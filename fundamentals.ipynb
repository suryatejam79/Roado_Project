# %% [markdown]
# FUNDAMENTALS in PYTHON

# %%
#Variables
x1 = 100
x2 = (x1*2) -30
x3 = (x1-x2)*3
x4 = x3-(x2-x1)
x1 = x4 - x2
x2 = x1 - x3
x3 = x1*x2*2

# %%
x4
# Out:
# -280

# %%
a = 5
b = a*4
if b > a +10:
    print("A")
    b = b-a
    if a*3 >= b:
        print("B")
        a = a+b
        if b*2 > a*3:
            print("C")
            b = a
c = a+b
print(a,b,c)
# Out:
# A
# B
# 20 15 35

# %%
if 8>4:
    print("test1")
elif 7>3:
    print("test2")
elif 8>3:
    print("test3")
else:
    print("test4")
# Out:
# test1

# %% [markdown]
# Data Types
# int
# float
# boolean
# complex
# string

# %% [markdown]
# String Data Types and Functions
# It is displayed in "", '',''' ''',
# Above are empty strings it is must usefull

# %%
x = "Hi My self Surya Teja"

# %%
x
# Out:
# 'Hi My self Surya Teja'

# %%
x.capitalize()
# Out:
# 'Hi my self surya teja'

# %%
x.title()
# Out:
# 'Hi My Self Surya Teja'

# %%
x = x.upper()

# %%
x
# Out:
# 'HI MY SELF SURYA TEJA'

# %%
x = x.lower()

# %%
x
# Out:
# 'hi my self surya teja'

# %%
x = x.title()

# %%
x
# Out:
# 'Hi My Self Surya Teja'

# %%
y = "$$$$$ my currency $$$ is USA $$$"

# %%
y = y.strip("$")

# %%
y = y.strip()

# %%
y
# Out:
# 'my currency $$$ is USA'

# %%
x = "Hello, Coder doing code"

# %%
x = x.replace("code","Python Code")

# %%
x = x.lower()

# %%
x
# Out:
# 'hello, coder doing python code'

# %%
x = x.replace(" ", "*")

# %%
x
# Out:
# 'hello,*coder*doing*python*code'

# %%
x = "Hello Coder Python"

# %%
x[1:8:1]
# Out:
# 'ello Co'

# %%
x[0:8:2]
# Out:
# 'HloC'

# %%
x[0:6]
# Out:
# 'Hello '

# %%
x[16:11]
# Out:
# ''

# %%
x[16:11:-1]
# Out:
# 'ohtyP'

# %%
x = [10,2.5
     ,"x",[20,3.14,"y",[30,4.5]],["a", 50,[60.6,"b"]],
     [70,[80,"c",[90.9]]],100]

# %%
x[-2][-1][-1][0]
# Out:
# 90.9

# %%
x[-3][-1][0] * x[3][-1][-1]
# Out:
# 272.7

# %%
x[3][-1][-1]
# Out:
# 4.5

# %%
x = [1,2,3,4,5,6,7,7,1]

# %%
if x[0] == x[-1]:
    print("Matched")
else:
    print("not matched")
# Out:
# Matched

# %%
x = [2,3,4]

# %%
if x[0]+x[1] < x[2]:
    print("Not triangle")
elif x[1]+x[2] < x[0]:
    print("not triangle")
elif x[0]+x[2] < x[1]:
    print("not triangle")
else:
    print("forms Triangle")
# Out:
# forms Triangle

# %%
if x[0]+x[1]>x[2] and x[1]+x[2]>x[0] and x[2]+x[0] > x[1]:
    print("forms triangle")
else:
    print("not forms triangle")
# Out:
# forms triangle
